# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/sms-spam-collection-dataset/spam.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/kaggle/input/sms-spam-collection-dataset/spam.csv', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.isnull().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
df.columns
# Out:
# Index(['v1', 'v2', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')

# %%
df.drop(columns = ['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.rename(columns={'v1': 'Category', 'v2': 'Message'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  5572 non-null   object
#  1   Message   5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Category'] = le.fit_transform(df['Category'])

# %%
df.head()
# Out:
#    Category                                            Message
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...

# %%
df.isnull().sum()
# Out:
# Category    0
# Message     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df.drop_duplicates(keep='first', inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 2)

# %%
df['Category'].value_counts()
# Out:
# Category
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['Category'].value_counts(), labels=['ham','spam'], autopct='%0.2f')
plt.show()

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['num_characters'] = df['Message'].apply(len)

# %%
df.head()
# Out:
#    Category                                            Message  num_characters
# 0         0  Go until jurong point, crazy.. Available only ...             111
# 1         0                      Ok lar... Joking wif u oni...              29
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3         0  U dun say so early hor... U c already then say...              49
# 4         0  Nah I don't think he goes to usf, he lives aro...              61

# %%
df['num_words'] = df['Message'].apply(lambda x : len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#    Category                                            Message  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
#
#    num_characters  num_words
# 0             111         24
# 1              29          8
# 2             155         37
# 3              49         13
# 4              61         15

# %%
df['num_sentences'] = df['Message'].apply(lambda x : len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    Category                                            Message  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
#
#    num_characters  num_words  num_sentences
# 0             111         24              2
# 1              29          8              2
# 2             155         37              2
# 3              49         13              1
# 4              61         15              1

# %%
df.describe()
# Out:
#           Category  num_characters    num_words  num_sentences
# count  5169.000000     5169.000000  5169.000000    5169.000000
# mean      0.126330       78.977945    18.455794       1.965564
# std       0.332253       58.236293    13.324758       1.448541
# min       0.000000        2.000000     1.000000       1.000000
# 25%       0.000000       36.000000     9.000000       1.000000
# 50%       0.000000       60.000000    15.000000       1.000000
# 75%       0.000000      117.000000    26.000000       2.000000
# max       1.000000      910.000000   220.000000      38.000000

# %%
sns.histplot(df[df['Category'] == 0]['num_characters'])
sns.histplot(df[df['Category'] == 1]['num_characters'], color='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
sns.histplot(df[df['Category'] == 0]['num_words'])
sns.histplot(df[df['Category'] == 1]['num_words'], color='red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df, hue='Category')

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
## Stemming
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('jumping')
# Out:
# 'jump'

# %%
def transform_text(text):
    text = text.lower()
    text = nltk.word_tokenize(text)
    
    y = []
    for i in text:
        if(i.isalnum()):
            y.append(i)
            
    text = y[:]
    y.clear()
    
    for i in text:
        if i not in stopwords.words('english') and i not in string.punctuation:
            y.append(i)
    
    text = y[:]
    y.clear()
    for i in text:
        y.append(ps.stem(i))
    
    
    return " ".join(y)

# %%
transform_text("I am walking and running!!!")
# Out:
# 'walk run'

# %%
df['transformed_text'] = df['Message'].apply(transform_text)

# %%
df.head()
# Out:
#    Category                                            Message  \
# 0         0  Go until jurong point, crazy.. Available only ...
# 1         0                      Ok lar... Joking wif u oni...
# 2         1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         0  U dun say so early hor... U c already then say...
# 4         0  Nah I don't think he goes to usf, he lives aro...
#
#    num_characters  num_words  num_sentences  \
# 0             111         24              2
# 1              29          8              2
# 2             155         37              2
# 3              49         13              1
# 4              61         15              1
#
#                                     transformed_text
# 0  go jurong point crazi avail bugi n great world...
# 1                              ok lar joke wif u oni
# 2  free entri 2 wkli comp win fa cup final tkt 21...
# 3                u dun say earli hor u c alreadi say
# 4               nah think goe usf live around though

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=3000)

# %%
X = cv.fit_transform(df['transformed_text']).toarray()

# %%
X.shape
# Out:
# (5169, 6708)

# %%
y = df['Category']

# %%
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 5567    1
# 5568    0
# 5569    0
# 5570    0
# 5571    0
# Name: Category, Length: 5169, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train , X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state=42)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost) (1.15.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->xgboost) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->xgboost) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->xgboost) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->xgboost) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->xgboost) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->xgboost) (2024.2.0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from xgboost import XGBClassifier

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Linear SVC": LinearSVC(),
    "SVC (Linear Kernel)": SVC(kernel='linear'),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Gaussian NB": GaussianNB(),
    "Multinomial NB": MultinomialNB(),
    "Bernoulli NB": BernoulliNB(),
    "AdaBoost": AdaBoostClassifier(),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss')
}

for name, model in models.items():
    model.fit(X_train, y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # ROC AUC using predicted probabilities when available
    try:
        roc_train = roc_auc_score(y_train, model.predict_proba(X_train)[:, 1])
        roc_test = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])
    except:
        roc_train = roc_auc_score(y_train, y_train_pred)
        roc_test = roc_auc_score(y_test, y_test_pred)

    print(f"🔍 Model: {name}")
    print("Training Performance:")
    print(f"  Accuracy  : {accuracy_score(y_train, y_train_pred):.4f}")
    print(f"  Precision : {precision_score(y_train, y_train_pred):.4f}")
    print(f"  Recall    : {recall_score(y_train, y_train_pred):.4f}")
    print(f"  F1 Score  : {f1_score(y_train, y_train_pred):.4f}")
    print(f"  ROC AUC   : {roc_train:.4f}")

    print("Test Performance:")
    print(f"  Accuracy  : {accuracy_score(y_test, y_test_pred):.4f}")
    print(f"  Precision : {precision_score(y_test, y_test_pred):.4f}")
    print(f"  Recall    : {recall_score(y_test, y_test_pred):.4f}")
    print(f"  F1 Score  : {f1_score(y_test, y_test_pred):.4f}")
    print(f"  ROC AUC   : {roc_test:.4f}")
    print("=" * 50)
# Out:
# 🔍 Model: Logistic Regression
# Training Performance:
#   Accuracy  : 0.9954
#   Precision : 1.0000
#   Recall    : 0.9615
#   F1 Score  : 0.9803
#   ROC AUC   : 0.9998
# Test Performance:
#   Accuracy  : 0.9791
#   Precision : 0.9877
#   Recall    : 0.8656
#   F1 Score  : 0.9226
#   ROC AUC   : 0.9862
# ==================================================
# 🔍 Model: Linear SVC
# Training Performance:
#   Accuracy  : 1.0000
#   Precision : 1.0000
#   Recall    : 1.0000
#   F1 Score  : 1.0000
#   ROC AUC   : 1.0000
# Test Performance:
#   Accuracy  : 0.9807
#   Precision : 0.9879
#   Recall    : 0.8763
#   F1 Score  : 0.9288
#   ROC AUC   : 0.9373
# ==================================================
# 🔍 Model: SVC (Linear Kernel)
# Training Performance:
#   Accuracy  : 0.9997
#   Precision : 1.0000
#   Recall    : 0.9979
#   F1 Score  : 0.9989
#   ROC AUC   : 0.9989
# Test Performance:
#   Accuracy  : 0.9807
#   Precision : 0.9879
#   Recall    : 0.8763
#   F1 Score  : 0.9288
#   ROC AUC   : 0.9373
# ==================================================
# 🔍 Model: Decision Tree
# Training Performance:
#   Accuracy  : 1.0000
#   Precision : 1.0000
#   Recall    : 1.0000
#   F1 Score  : 1.0000
#   ROC AUC   : 1.0000
# Test Performance:
#   Accuracy  : 0.9606
#   Precision : 0.8771
#   Recall    : 0.8441
#   F1 Score  : 0.8603
#   ROC AUC   : 0.9121
# ==================================================
# 🔍 Model: Random Forest
# Training Performance:
#   Accuracy  : 1.0000
#   Precision : 1.0000
#   Recall    : 1.0000
#   F1 Score  : 1.0000
#   ROC AUC   : 1.0000
# Test Performance:
#   Accuracy  : 0.9660
#   Precision : 0.9931
#   Recall    : 0.7688
#   F1 Score  : 0.8667
#   ROC AUC   : 0.9794
# ==================================================
# 🔍 Model: Gaussian NB
# Training Performance:
#   Accuracy  : 0.9288
#   Precision : 0.6285
#   Recall    : 1.0000
#   F1 Score  : 0.7719
#   ROC AUC   : 0.9595
# Test Performance:
#   Accuracy  : 0.8732
#   Precision : 0.5367
#   Recall    : 0.8656
#   F1 Score  : 0.6626
#   ROC AUC   : 0.8700
# ==================================================
# 🔍 Model: Multinomial NB
# Training Performance:
#   Accuracy  : 0.9936
#   Precision : 0.9825
#   Recall    : 0.9636
#   F1 Score  : 0.9730
#   ROC AUC   : 0.9946
# Test Performance:
#   Accuracy  : 0.9729
#   Precision : 0.8995
#   Recall    : 0.9140
#   F1 Score  : 0.9067
#   ROC AUC   : 0.9747
# ==================================================
# 🔍 Model: Bernoulli NB
# Training Performance:
#   Accuracy  : 0.9770
#   Precision : 0.9922
#   Recall    : 0.8158
#   F1 Score  : 0.8954
#   ROC AUC   : 0.9973
# Test Performance:
#   Accuracy  : 0.9652
#   Precision : 0.9732
#   Recall    : 0.7796
#   F1 Score  : 0.8657
#   ROC AUC   : 0.9899
# ==================================================
# 🔍 Model: AdaBoost
# Training Performance:
#   Accuracy  : 0.9734
#   Precision : 0.9483
#   Recall    : 0.8244
#   F1 Score  : 0.8820
#   ROC AUC   : 0.9936
# Test Performance:
#   Accuracy  : 0.9551
#   Precision : 0.9103
#   Recall    : 0.7634
#   F1 Score  : 0.8304
#   ROC AUC   : 0.9664
# ==================================================
# 🔍 Model: XGBoost
# Training Performance:
#   Accuracy  : 0.9884
#   Precision : 0.9976
#   Recall    : 0.9058
#   F1 Score  : 0.9495
#   ROC AUC   : 0.9924
# Test Performance:
#   Accuracy  : 0.9722
#   Precision : 0.9464
#   Recall    : 0.8548
#   F1 Score  : 0.8983
#   ROC AUC   : 0.9811
# ==================================================

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# Hyperparameter grids
lr_params = {
    "penalty": ["l2"],
    "C": [0.01, 0.1, 1, 10, 100],
    "solver": ["lbfgs", "liblinear"]
}

dt_params = {
    "max_depth": [3, 5, 10, None],
    "min_samples_split": [2, 5, 10],
    "criterion": ["gini", "entropy"]
}

rf_params = {
    "max_depth": [5, 8, 10, 15, None],
    "max_features": [5, 7, "auto"],
    "min_samples_split": [2, 8, 15, 20],
    "n_estimators": [100, 200, 500, 1000]
}

ada_params = {
    "n_estimators": [50, 100, 200],
    "learning_rate": [0.01, 0.1, 1, 2]
}

xgb_params = {
    "n_estimators": [100, 200, 500],
    "max_depth": [3, 6, 10],
    "learning_rate": [0.01, 0.1, 0.3],
    "subsample": [0.7, 1],
    "colsample_bytree": [0.7, 1]
}

nb_params = {
    "MultinomialNB": {"alpha": [0.0, 0.5, 1.0, 2.0]},
    "BernoulliNB": {"alpha": [0.0, 0.5, 1.0], "binarize": [0.0, 0.5, 1.0]},
    "GaussianNB": {"var_smoothing": [1e-9, 1e-8, 1e-7]}
}

# %%
randomcv_models = [
    ("Logistic Regression", LogisticRegression(max_iter=1000), lr_params),
    ("Linear SVC", LinearSVC(), {"C": [0.01, 0.1, 1, 10]}),
    ("SVC (Linear Kernel)", SVC(kernel='linear', probability=True), {"C": [0.01, 0.1, 1, 10]}),
    ("Decision Tree", DecisionTreeClassifier(), dt_params),
    ("Random Forest", RandomForestClassifier(), rf_params),
    ("AdaBoost", AdaBoostClassifier(), ada_params),
    ("XGBoost", XGBClassifier(use_label_encoder=False, eval_metric='logloss'), xgb_params),
    ("MultinomialNB", MultinomialNB(), nb_params["MultinomialNB"]),
    ("BernoulliNB", BernoulliNB(), nb_params["BernoulliNB"]),
    ("GaussianNB", GaussianNB(), nb_params["GaussianNB"])
]

# %%
model_param = {}

# Perform RandomizedSearchCV for each model
for name, model, params in randomcv_models:
    print(f"\n Tuning: {name}")
    random = RandomizedSearchCV(estimator=model,
                                param_distributions=params,
                                n_iter=50,
                                cv=3,
                                verbose=2,
                                n_jobs=-1,
                                scoring='f1_weighted')  # you can change the scoring as needed
    random.fit(X_train, y_train)
    model_param[name] = random.best_params_

# Display the best parameters for each model
for model_name in model_param:
    print(f"\n---------------- Best Params for {model_name} -------------------")
    print(model_param[model_name])
# Out:
#  Tuning: Logistic Regression
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] END ...................C=0.01, penalty=l2, solver=lbfgs; total time=   0.5s
# [CV] END ...............C=0.01, penalty=l2, solver=liblinear; total time=   0.5s
# [CV] END ...................C=0.01, penalty=l2, solver=lbfgs; total time=   0.7s
# [CV] END ...................C=0.01, penalty=l2, solver=lbfgs; total time=   0.7s
# [CV] END ...............C=0.01, penalty=l2, solver=liblinear; total time=   0.4s
# [CV] END ...............C=0.01, penalty=l2, solver=liblinear; total time=   0.4s
# [CV] END ................C=0.1, penalty=l2, solver=liblinear; total time=   0.5s
# [CV] END ....................C=0.1, penalty=l2, solver=lbfgs; total time=   1.0s
# [CV] END ....................C=0.1, penalty=l2, solver=lbfgs; total time=   1.0s
# [CV] END ....................C=0.1, penalty=l2, solver=lbfgs; total time=   0.8s
# [CV] END ................C=0.1, penalty=l2, solver=liblinear; total time=   0.5s
# [CV] END ................C=0.1, penalty=l2, solver=liblinear; total time=   0.5s
# [CV] END ..................C=1, penalty=l2, solver=liblinear; total time=   0.5s
# [CV] END ......................C=1, penalty=l2, solver=lbfgs; total time=   1.3s
# [CV] END ..................C=1, penalty=l2, solver=liblinear; total time=   0.5s
# [CV] END ......................C=1, penalty=l2, solver=lbfgs; total time=   1.7s
# [CV] END ..................C=1, penalty=l2, solver=liblinear; total time=   0.4s
# [CV] END ......................C=1, penalty=l2, solver=lbfgs; total time=   1.7s
# [CV] END .................C=10, penalty=l2, solver=liblinear; total time=   0.5s
# [CV] END .................C=10, penalty=l2, solver=liblinear; total time=   0.5s
# [CV] END .................C=10, penalty=l2, solver=liblinear; total time=   0.5s
# [CV] END .....................C=10, penalty=l2, solver=lbfgs; total time=   1.8s
# [CV] END .....................C=10, penalty=l2, solver=lbfgs; total time=   2.1s
# [CV] END .....................C=10, penalty=l2, solver=lbfgs; total time=   2.3s
# [CV] END ................C=100, penalty=l2, solver=liblinear; total time=   0.5s
# [CV] END ................C=100, penalty=l2, solver=liblinear; total time=   0.5s
# [CV] END ................C=100, penalty=l2, solver=liblinear; total time=   0.5s
# [CV] END ....................C=100, penalty=l2, solver=lbfgs; total time=   2.2s
# [CV] END ....................C=100, penalty=l2, solver=lbfgs; total time=   2.5s
# [CV] END ....................C=100, penalty=l2, solver=lbfgs; total time=   2.5s
#
#  Tuning: Linear SVC
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [CV] END ..............................................C=0.1; total time=   0.4s
# [CV] END .............................................C=0.01; total time=   0.4s
# [CV] END .............................................C=0.01; total time=   0.4s
# [CV] END .............................................C=0.01; total time=   0.4s
# [CV] END ..............................................C=0.1; total time=   0.4s
# [CV] END ..............................................C=0.1; total time=   0.4s
# [CV] END ................................................C=1; total time=   0.4s
# [CV] END ................................................C=1; total time=   0.4s
# [CV] END ................................................C=1; total time=   0.4s
# [CV] END ...............................................C=10; total time=   0.4s
# [CV] END ...............................................C=10; total time=   0.4s
# [CV] END ...............................................C=10; total time=   0.4s
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
#  Tuning: SVC (Linear Kernel)
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [CV] END ..............................................C=0.1; total time= 1.0min
# [CV] END .............................................C=0.01; total time= 1.4min
# [CV] END .............................................C=0.01; total time= 1.4min
# [CV] END .............................................C=0.01; total time= 1.4min
# [CV] END ..............................................C=0.1; total time= 1.1min
# [CV] END ................................................C=1; total time=  55.5s
# [CV] END ................................................C=1; total time=  58.7s
# [CV] END ..............................................C=0.1; total time= 1.0min
# [CV] END ................................................C=1; total time=  56.5s
# [CV] END ...............................................C=10; total time=  46.2s
# [CV] END ...............................................C=10; total time=  53.0s
# [CV] END ...............................................C=10; total time=  48.7s
#
#  Tuning: Decision Tree
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=5; total time=   1.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=2; total time=   1.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=2; total time=   1.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=2; total time=   1.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=10; total time=   1.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=5; total time=   1.0s
# [CV] END ...criterion=gini, max_depth=3, min_samples_split=5; total time=   1.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=10; total time=   1.0s
# [CV] END ..criterion=gini, max_depth=3, min_samples_split=10; total time=   1.0s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=2; total time=   1.3s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=2; total time=   1.3s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=2; total time=   1.3s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=5; total time=   1.3s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=5; total time=   1.3s
# [CV] END ...criterion=gini, max_depth=5, min_samples_split=5; total time=   1.3s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=10; total time=   1.3s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=10; total time=   1.3s
# [CV] END ..criterion=gini, max_depth=5, min_samples_split=10; total time=   1.3s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=2; total time=   2.1s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=2; total time=   2.2s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=2; total time=   2.1s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=5; total time=   2.1s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=5; total time=   2.2s
# [CV] END ..criterion=gini, max_depth=10, min_samples_split=5; total time=   2.2s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   2.1s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   2.1s
# [CV] END .criterion=gini, max_depth=10, min_samples_split=10; total time=   2.1s
# [CV] END criterion=gini, max_depth=None, min_samples_split=2; total time=   7.2s
# [CV] END criterion=gini, max_depth=None, min_samples_split=2; total time=   7.2s
# [CV] END criterion=gini, max_depth=None, min_samples_split=2; total time=   8.4s
# [CV] END criterion=gini, max_depth=None, min_samples_split=5; total time=   7.6s
# [CV] END criterion=gini, max_depth=None, min_samples_split=5; total time=   8.0s
# [CV] END criterion=gini, max_depth=None, min_samples_split=5; total time=   7.4s
# [CV] END criterion=entropy, max_depth=3, min_samples_split=2; total time=   0.9s
# [CV] END criterion=gini, max_depth=None, min_samples_split=10; total time=   7.5s
# [CV] END criterion=entropy, max_depth=3, min_samples_split=2; total time=   1.0s
# [CV] END criterion=entropy, max_depth=3, min_samples_split=2; total time=   1.0s
# [CV] END criterion=gini, max_depth=None, min_samples_split=10; total time=   8.3s
# [CV] END criterion=entropy, max_depth=3, min_samples_split=5; total time=   1.0s
# [CV] END criterion=entropy, max_depth=3, min_samples_split=5; total time=   1.0s
# [CV] END criterion=entropy, max_depth=3, min_samples_split=5; total time=   1.0s
# [CV] END criterion=entropy, max_depth=3, min_samples_split=10; total time=   1.0s
# [CV] END criterion=entropy, max_depth=3, min_samples_split=10; total time=   1.0s
# [CV] END criterion=entropy, max_depth=3, min_samples_split=10; total time=   1.0s
# [CV] END criterion=entropy, max_depth=5, min_samples_split=2; total time=   1.3s
# [CV] END criterion=entropy, max_depth=5, min_samples_split=2; total time=   1.3s
# [CV] END criterion=entropy, max_depth=5, min_samples_split=2; total time=   1.3s
# [CV] END criterion=gini, max_depth=None, min_samples_split=10; total time=   7.0s
# [CV] END criterion=entropy, max_depth=5, min_samples_split=5; total time=   1.3s
# [CV] END criterion=entropy, max_depth=5, min_samples_split=5; total time=   1.3s
# [CV] END criterion=entropy, max_depth=5, min_samples_split=5; total time=   1.3s
# [CV] END criterion=entropy, max_depth=5, min_samples_split=10; total time=   1.4s
# [CV] END criterion=entropy, max_depth=5, min_samples_split=10; total time=   1.3s
# [CV] END criterion=entropy, max_depth=5, min_samples_split=10; total time=   1.4s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=2; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=5; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10; total time=   2.1s
# [CV] END criterion=entropy, max_depth=10, min_samples_split=10; total time=   2.1s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=2; total time=   5.9s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=2; total time=   5.8s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=2; total time=   5.9s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=5; total time=   5.8s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=5; total time=   5.8s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   5.8s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=5; total time=   6.1s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   5.5s
# [CV] END criterion=entropy, max_depth=None, min_samples_split=10; total time=   2.7s
#
#  Tuning: Random Forest
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=500; total time=   2.9s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=500; total time=   3.0s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=500; total time=   3.1s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=8, max_features=auto, min_samples_split=2, n_estimators=500; total time=  10.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=200; total time=  10.8s
# [CV] END max_depth=8, max_features=auto, min_samples_split=2, n_estimators=500; total time=  11.5s
# [CV] END max_depth=8, max_features=auto, min_samples_split=2, n_estimators=500; total time=  11.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=100; total time=   4.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=100; total time=   5.0s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=200; total time=  10.3s
# [CV] END max_depth=8, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=200; total time=  10.4s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=100; total time=   5.5s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=1000; total time=   5.4s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=1000; total time=   5.1s
# [CV] END max_depth=10, max_features=5, min_samples_split=20, n_estimators=1000; total time=   4.8s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=500; total time=   2.5s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=500; total time=   2.4s
# [CV] END max_depth=None, max_features=5, min_samples_split=8, n_estimators=200; total time=   9.6s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=200; total time=   1.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=8, n_estimators=200; total time=   9.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=8, n_estimators=200; total time=   9.8s
# [CV] END max_depth=10, max_features=5, min_samples_split=8, n_estimators=500; total time=   2.5s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.2s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=200; total time=   1.5s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=200; total time=   1.5s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.2s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.2s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=200; total time=   1.0s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=500; total time=   2.3s
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=500; total time=   2.4s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=8, max_features=5, min_samples_split=2, n_estimators=500; total time=   2.3s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, max_features=7, min_samples_split=20, n_estimators=200; total time=   1.0s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=8, max_features=auto, min_samples_split=8, n_estimators=200; total time=   4.7s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=8, max_features=auto, min_samples_split=8, n_estimators=200; total time=   4.7s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=500; total time=  11.2s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=500; total time=  11.2s
# [CV] END max_depth=8, max_features=auto, min_samples_split=20, n_estimators=500; total time=  11.2s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=500; total time=   2.9s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=8, max_features=auto, min_samples_split=8, n_estimators=200; total time=   4.3s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=500; total time=   3.1s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=500; total time=   3.1s
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.6s
# [CV] END max_depth=5, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.6s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=100; total time=   3.2s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=100; total time=   2.7s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=100; total time=   3.1s
# [CV] END max_depth=8, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.7s
# [CV] END max_depth=8, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.7s
# [CV] END max_depth=8, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.7s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=1000; total time=   7.1s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=1000; total time=  14.3s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=1000; total time=  15.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=1000; total time=  15.0s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=1000; total time=   6.9s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=500; total time=   2.5s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=500; total time=   2.5s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=500; total time=   2.5s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=1000; total time=   6.9s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=200; total time=  28.9s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=200; total time=  31.4s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=200; total time=  30.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=100; total time=   0.8s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=500; total time= 1.3min
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=1000; total time= 2.5min
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=1000; total time= 2.5min
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_split=8, n_estimators=1000; total time= 2.5min
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200; total time=   5.6s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200; total time=   5.4s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=500; total time= 1.3min
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200; total time=   5.6s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=100; total time=   5.7s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=100; total time=   5.7s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=100; total time=   6.2s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=500; total time= 1.2min
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=1000; total time=  56.6s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=1000; total time= 2.4min
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=1000; total time=  56.7s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=100; total time=   1.5s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=1000; total time= 2.5min
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=100; total time=   1.8s
# [CV] END max_depth=5, max_features=auto, min_samples_split=15, n_estimators=100; total time=   1.7s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=1000; total time= 2.5min
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=1000; total time=   6.8s
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=1000; total time=   6.9s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=15, max_features=7, min_samples_split=8, n_estimators=1000; total time=   6.7s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=500; total time=   7.7s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=500; total time=   7.8s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=15, max_features=7, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=5, max_features=auto, min_samples_split=20, n_estimators=500; total time=   7.4s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=1000; total time=  52.2s
# [CV] END max_depth=8, max_features=5, min_samples_split=8, n_estimators=200; total time=   1.0s
# [CV] END max_depth=8, max_features=5, min_samples_split=8, n_estimators=200; total time=   1.1s
# [CV] END max_depth=8, max_features=5, min_samples_split=8, n_estimators=200; total time=   1.0s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=1000; total time=   4.5s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=1000; total time=   4.8s
# [CV] END max_depth=8, max_features=5, min_samples_split=20, n_estimators=1000; total time=   3.9s
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.3s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=1000; total time=  47.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=1000; total time=  48.9s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.5s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=15, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.5s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=1000; total time=  49.6s
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=100; total time=   3.3s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=100; total time=   3.9s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_split=2, n_estimators=100; total time=   4.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=100; total time=  14.8s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=200; total time=  12.8s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=100; total time=  14.9s
# [CV] END max_depth=None, max_features=auto, min_samples_split=20, n_estimators=100; total time=  13.9s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.8s
# [CV] END max_depth=15, max_features=7, min_samples_split=20, n_estimators=100; total time=   0.9s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=200; total time=   1.3s
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=200; total time=   1.3s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=10, max_features=7, min_samples_split=20, n_estimators=200; total time=   1.2s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=200; total time=  11.6s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=200; total time=  12.7s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=500; total time=   2.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=500; total time=  13.4s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=500; total time=   2.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=500; total time=  13.0s
# [CV] END max_depth=5, max_features=5, min_samples_split=15, n_estimators=500; total time=   2.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=1000; total time=   5.2s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=1000; total time=   5.3s
# [CV] END max_depth=10, max_features=auto, min_samples_split=8, n_estimators=500; total time=  12.1s
# [CV] END max_depth=10, max_features=7, min_samples_split=8, n_estimators=1000; total time=   5.5s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=5, min_samples_split=20, n_estimators=100; total time=   4.9s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=5, min_samples_split=20, n_estimators=100; total time=   4.7s
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# [CV] END max_depth=None, max_features=5, min_samples_split=20, n_estimators=100; total time=   5.0s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, max_features=auto, min_samples_split=8, n_estimators=500; total time=   7.4s
# [CV] END max_depth=5, max_features=7, min_samples_split=8, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.8s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.8s
# [CV] END max_depth=15, max_features=5, min_samples_split=20, n_estimators=100; total time=   0.8s
# [CV] END max_depth=5, max_features=auto, min_samples_split=8, n_estimators=500; total time=   7.7s
# [CV] END max_depth=5, max_features=auto, min_samples_split=8, n_estimators=500; total time=   7.7s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=500; total time=   3.0s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=500; total time=   2.6s
# [CV] END max_depth=15, max_features=5, min_samples_split=8, n_estimators=500; total time=   2.1s
#
#  Tuning: AdaBoost
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  25.0s
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  25.1s
# [CV] END ................learning_rate=0.01, n_estimators=50; total time=  25.8s
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=  51.4s
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=  49.9s
# [CV] END ...............learning_rate=0.01, n_estimators=100; total time=  51.1s
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  25.0s
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  24.8s
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 1.7min
# [CV] END .................learning_rate=0.1, n_estimators=50; total time=  25.5s
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 1.7min
# [CV] END ...............learning_rate=0.01, n_estimators=200; total time= 1.7min
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=  51.1s
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=  51.1s
# [CV] END ................learning_rate=0.1, n_estimators=100; total time=  50.5s
# [CV] END ...................learning_rate=1, n_estimators=50; total time=  25.5s
# [CV] END ...................learning_rate=1, n_estimators=50; total time=  26.4s
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 1.7min
# [CV] END ...................learning_rate=1, n_estimators=50; total time=  24.8s
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 1.7min
# [CV] END ................learning_rate=0.1, n_estimators=200; total time= 1.6min
# [CV] END ..................learning_rate=1, n_estimators=100; total time=  50.3s
# [CV] END ..................learning_rate=1, n_estimators=100; total time=  51.2s
# [CV] END ..................learning_rate=1, n_estimators=100; total time=  51.9s
# [CV] END ...................learning_rate=2, n_estimators=50; total time=  25.4s
# [CV] END ...................learning_rate=2, n_estimators=50; total time=  26.0s
# [CV] END ..................learning_rate=1, n_estimators=200; total time= 1.7min
# [CV] END ...................learning_rate=2, n_estimators=50; total time=  25.6s
# [CV] END ..................learning_rate=1, n_estimators=200; total time= 1.7min
# [CV] END ..................learning_rate=1, n_estimators=200; total time= 1.7min
# [CV] END ..................learning_rate=2, n_estimators=100; total time=  50.3s
# [CV] END ..................learning_rate=2, n_estimators=100; total time=  51.1s
# [CV] END ..................learning_rate=2, n_estimators=100; total time=  50.2s
# [CV] END ..................learning_rate=2, n_estimators=200; total time= 1.4min
# [CV] END ..................learning_rate=2, n_estimators=200; total time= 1.3min
# [CV] END ..................learning_rate=2, n_estimators=200; total time= 1.3min
#
#  Tuning: XGBoost
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=1; total time=  11.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=1; total time=  11.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=1; total time=  12.0s
# [CV] END colsample_bytree=1, learning_rate=0.3, max_depth=3, n_estimators=500, subsample=1; total time=  17.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   5.9s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   6.0s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=6, n_estimators=100, subsample=0.7; total time=   6.1s
# [CV] END colsample_bytree=1, learning_rate=0.3, max_depth=3, n_estimators=500, subsample=1; total time=  16.5s
# [CV] END colsample_bytree=1, learning_rate=0.3, max_depth=3, n_estimators=500, subsample=1; total time=  16.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.7; total time=   6.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.7; total time=   6.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.7; total time=   6.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=6, n_estimators=200, subsample=0.7; total time=   9.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=6, n_estimators=200, subsample=0.7; total time=   9.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=6, n_estimators=200, subsample=0.7; total time=   9.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100, subsample=0.7; total time=   5.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100, subsample=0.7; total time=   5.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1; total time=  19.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=1; total time=  19.3s
# ...
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=100, subsample=1; total time=   7.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=100, subsample=1; total time=   7.3s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=100, subsample=1; total time=   7.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=200, subsample=0.7; total time=   9.0s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1; total time=   5.2s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.7; total time=  11.2s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.7; total time=  11.0s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=200, subsample=0.7; total time=  11.3s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1; total time=   5.3s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=3, n_estimators=100, subsample=1; total time=   5.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100, subsample=1; total time=   6.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100, subsample=1; total time=   5.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100, subsample=1; total time=   6.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100, subsample=0.7; total time=   5.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.7; total time=   8.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.7; total time=   8.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=200, subsample=0.7; total time=   8.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100, subsample=0.7; total time=   5.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100, subsample=0.7; total time=   6.2s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=0.7; total time=   9.9s
# [CV] END colsample_bytree=1, learning_rate=0.3, max_depth=10, n_estimators=500, subsample=0.7; total time=  22.7s
# [CV] END colsample_bytree=1, learning_rate=0.3, max_depth=10, n_estimators=500, subsample=0.7; total time=  23.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=0.7; total time=  10.1s
# [CV] END colsample_bytree=1, learning_rate=0.3, max_depth=10, n_estimators=500, subsample=0.7; total time=  22.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=200, subsample=0.7; total time=  10.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.3, max_depth=3, n_estimators=100, subsample=0.7; total time=   5.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.3, max_depth=3, n_estimators=100, subsample=0.7; total time=   5.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.7; total time=  21.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.7; total time=  21.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.3, max_depth=3, n_estimators=100, subsample=0.7; total time=   5.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=0.7; total time=  21.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.7; total time=  19.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.7; total time=  18.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500, subsample=0.7; total time=  19.8s
# [CV] END colsample_bytree=1, learning_rate=0.3, max_depth=6, n_estimators=500, subsample=0.7; total time=  20.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.7; total time=   6.6s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.7; total time=   6.7s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.7; total time=   6.7s
# [CV] END colsample_bytree=1, learning_rate=0.3, max_depth=6, n_estimators=500, subsample=0.7; total time=  19.4s
# [CV] END colsample_bytree=1, learning_rate=0.3, max_depth=6, n_estimators=500, subsample=0.7; total time=  19.4s
# [CV] END colsample_bytree=1, learning_rate=0.3, max_depth=10, n_estimators=200, subsample=0.7; total time=  11.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=1; total time=  24.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=1; total time=  24.3s
# [CV] END colsample_bytree=1, learning_rate=0.3, max_depth=10, n_estimators=200, subsample=0.7; total time=  10.4s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=10, n_estimators=500, subsample=1; total time=  24.1s
# [CV] END colsample_bytree=1, learning_rate=0.3, max_depth=10, n_estimators=200, subsample=0.7; total time=   8.3s
#
#  Tuning: MultinomialNB
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:629: FutureWarning: The default value for `force_alpha` will change to `True` in 1.4. To suppress this warning, manually set the value of `force_alpha`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:635: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10. Use `force_alpha=True` to keep alpha unchanged.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:629: FutureWarning: The default value for `force_alpha` will change to `True` in 1.4. To suppress this warning, manually set the value of `force_alpha`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:635: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10. Use `force_alpha=True` to keep alpha unchanged.
#   warnings.warn(
# [CV] END ..........................................alpha=0.5; total time=   0.3s
# [CV] END ..........................................alpha=0.0; total time=   0.3s
# [CV] END ..........................................alpha=0.0; total time=   0.4s
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:629: FutureWarning: The default value for `force_alpha` will change to `True` in 1.4. To suppress this warning, manually set the value of `force_alpha`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:635: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10. Use `force_alpha=True` to keep alpha unchanged.
#   warnings.warn(
# [CV] END ..........................................alpha=0.0; total time=   0.6s
# [CV] END ..........................................alpha=1.0; total time=   0.3s
# [CV] END ..........................................alpha=0.5; total time=   0.4s
# [CV] END ..........................................alpha=0.5; total time=   0.6s
# [CV] END ..........................................alpha=1.0; total time=   0.3s
# [CV] END ..........................................alpha=2.0; total time=   0.3s
# [CV] END ..........................................alpha=1.0; total time=   0.5s
# [CV] END ..........................................alpha=2.0; total time=   0.2s
# [CV] END ..........................................alpha=2.0; total time=   0.5s
#
#  Tuning: BernoulliNB
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:629: FutureWarning: The default value for `force_alpha` will change to `True` in 1.4. To suppress this warning, manually set the value of `force_alpha`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:635: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10. Use `force_alpha=True` to keep alpha unchanged.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:629: FutureWarning: The default value for `force_alpha` will change to `True` in 1.4. To suppress this warning, manually set the value of `force_alpha`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:635: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10. Use `force_alpha=True` to keep alpha unchanged.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:629: FutureWarning: The default value for `force_alpha` will change to `True` in 1.4. To suppress this warning, manually set the value of `force_alpha`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:635: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10. Use `force_alpha=True` to keep alpha unchanged.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:629: FutureWarning: The default value for `force_alpha` will change to `True` in 1.4. To suppress this warning, manually set the value of `force_alpha`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:635: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10. Use `force_alpha=True` to keep alpha unchanged.
#   warnings.warn(
# [CV] END ............................alpha=0.0, binarize=0.0; total time=   0.6s
# [CV] END ............................alpha=0.0, binarize=0.5; total time=   0.6s
# [CV] END ............................alpha=0.0, binarize=0.0; total time=   0.6s
# [CV] END ............................alpha=0.0, binarize=0.0; total time=   0.7s
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:629: FutureWarning: The default value for `force_alpha` will change to `True` in 1.4. To suppress this warning, manually set the value of `force_alpha`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:635: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10. Use `force_alpha=True` to keep alpha unchanged.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:629: FutureWarning: The default value for `force_alpha` will change to `True` in 1.4. To suppress this warning, manually set the value of `force_alpha`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:635: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10. Use `force_alpha=True` to keep alpha unchanged.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:629: FutureWarning: The default value for `force_alpha` will change to `True` in 1.4. To suppress this warning, manually set the value of `force_alpha`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:635: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10. Use `force_alpha=True` to keep alpha unchanged.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:629: FutureWarning: The default value for `force_alpha` will change to `True` in 1.4. To suppress this warning, manually set the value of `force_alpha`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:635: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10. Use `force_alpha=True` to keep alpha unchanged.
#   warnings.warn(
# [CV] END ............................alpha=0.0, binarize=0.5; total time=   0.6s
# [CV] END ............................alpha=0.0, binarize=0.5; total time=   0.7s
# [CV] END ............................alpha=0.0, binarize=1.0; total time=   0.7s
# [CV] END ............................alpha=0.0, binarize=1.0; total time=   0.8s
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:629: FutureWarning: The default value for `force_alpha` will change to `True` in 1.4. To suppress this warning, manually set the value of `force_alpha`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/naive_bayes.py:635: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10. Use `force_alpha=True` to keep alpha unchanged.
#   warnings.warn(
# [CV] END ............................alpha=0.0, binarize=1.0; total time=   0.7s
# [CV] END ............................alpha=0.5, binarize=0.0; total time=   0.7s
# [CV] END ............................alpha=0.5, binarize=0.0; total time=   0.8s
# [CV] END ............................alpha=0.5, binarize=0.0; total time=   0.9s
# [CV] END ............................alpha=0.5, binarize=0.5; total time=   0.5s
# [CV] END ............................alpha=0.5, binarize=0.5; total time=   0.9s
# [CV] END ............................alpha=0.5, binarize=0.5; total time=   0.7s
# [CV] END ............................alpha=0.5, binarize=1.0; total time=   0.8s
# [CV] END ............................alpha=0.5, binarize=1.0; total time=   0.7s
# [CV] END ............................alpha=1.0, binarize=0.0; total time=   0.6s
# [CV] END ............................alpha=0.5, binarize=1.0; total time=   0.7s
# [CV] END ............................alpha=1.0, binarize=0.0; total time=   0.7s
# [CV] END ............................alpha=1.0, binarize=0.0; total time=   0.6s
# [CV] END ............................alpha=1.0, binarize=0.5; total time=   0.7s
# [CV] END ............................alpha=1.0, binarize=0.5; total time=   0.6s
# [CV] END ............................alpha=1.0, binarize=0.5; total time=   0.6s
# [CV] END ............................alpha=1.0, binarize=1.0; total time=   0.6s
# [CV] END ............................alpha=1.0, binarize=1.0; total time=   0.5s
# [CV] END ............................alpha=1.0, binarize=1.0; total time=   0.6s
#
#  Tuning: GaussianNB
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV] END ................................var_smoothing=1e-08; total time=   1.1s
# [CV] END ................................var_smoothing=1e-09; total time=   1.1s
# [CV] END ................................var_smoothing=1e-09; total time=   1.1s
# [CV] END ................................var_smoothing=1e-09; total time=   1.1s
# [CV] END ................................var_smoothing=1e-08; total time=   1.1s
# [CV] END ................................var_smoothing=1e-07; total time=   1.1s
# [CV] END ................................var_smoothing=1e-08; total time=   1.1s
# [CV] END ................................var_smoothing=1e-07; total time=   1.1s
# [CV] END ................................var_smoothing=1e-07; total time=   0.5s
#
# ---------------- Best Params for Logistic Regression -------------------
# {'solver': 'liblinear', 'penalty': 'l2', 'C': 100}
#
# ---------------- Best Params for Linear SVC -------------------
# {'C': 1}
#
# ---------------- Best Params for SVC (Linear Kernel) -------------------
# {'C': 1}
#
# ---------------- Best Params for Decision Tree -------------------
# {'min_samples_split': 2, 'max_depth': None, 'criterion': 'gini'}
#
# ---------------- Best Params for Random Forest -------------------
# {'n_estimators': 1000, 'min_samples_split': 8, 'max_features': 'auto', 'max_depth': None}
#
# ---------------- Best Params for AdaBoost -------------------
# {'n_estimators': 200, 'learning_rate': 1}
#
# ---------------- Best Params for XGBoost -------------------
# {'subsample': 1, 'n_estimators': 500, 'max_depth': 3, 'learning_rate': 0.1, 'colsample_bytree': 1}
#
# ---------------- Best Params for MultinomialNB -------------------
# {'alpha': 2.0}
#
# ---------------- Best Params for BernoulliNB -------------------
# {'binarize': 0.0, 'alpha': 0.0}
#
# ---------------- Best Params for GaussianNB -------------------
# {'var_smoothing': 1e-09}

# %%
models = {
    "Logistic Regression": LogisticRegression(solver='liblinear', penalty='l2', C=100, max_iter=1000),
    "Linear SVC": LinearSVC(C=1),
    "SVC (Linear Kernel)": SVC(kernel='linear', C=1),
    "Decision Tree": DecisionTreeClassifier(min_samples_split=2, max_depth=None, criterion='gini'),
    "Random Forest": RandomForestClassifier(n_estimators=1000, min_samples_split=8, max_features='auto', max_depth=None),
    "Gaussian NB": GaussianNB(var_smoothing=1e-09),
    "Multinomial NB": MultinomialNB(alpha=2.0),
    "Bernoulli NB": BernoulliNB(binarize=0.0, alpha=0.0),
    "AdaBoost": AdaBoostClassifier(n_estimators=200, learning_rate=1),
    "XGBoost": XGBClassifier(subsample=1, n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=1, use_label_encoder=False, eval_metric='logloss')
}

for name, model in models.items():
    model.fit(X_train, y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    # ROC AUC using predicted probabilities when available
    try:
        roc_train = roc_auc_score(y_train, model.predict_proba(X_train)[:, 1])
        roc_test = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])
    except:
        roc_train = roc_auc_score(y_train, y_train_pred)
        roc_test = roc_auc_score(y_test, y_test_pred)

    print(f"🔍 Model: {name}")
    print("Training Performance:")
    print(f"  Accuracy  : {accuracy_score(y_train, y_train_pred):.4f}")
    print(f"  Precision : {precision_score(y_train, y_train_pred):.4f}")
    print(f"  Recall    : {recall_score(y_train, y_train_pred):.4f}")
    print(f"  F1 Score  : {f1_score(y_train, y_train_pred):.4f}")
    print(f"  ROC AUC   : {roc_train:.4f}")

    print("Test Performance:")
    print(f"  Accuracy  : {accuracy_score(y_test, y_test_pred):.4f}")
    print(f"  Precision : {precision_score(y_test, y_test_pred):.4f}")
    print(f"  Recall    : {recall_score(y_test, y_test_pred):.4f}")
    print(f"  F1 Score  : {f1_score(y_test, y_test_pred):.4f}")
    print(f"  ROC AUC   : {roc_test:.4f}")
    print("=" * 50)
# Out:
# 🔍 Model: Logistic Regression
# Training Performance:
#   Accuracy  : 1.0000
#   Precision : 1.0000
#   Recall    : 1.0000
#   F1 Score  : 1.0000
#   ROC AUC   : 1.0000
# Test Performance:
#   Accuracy  : 0.9799
#   Precision : 0.9938
#   Recall    : 0.8656
#   F1 Score  : 0.9253
#   ROC AUC   : 0.9852
# ==================================================
# 🔍 Model: Linear SVC
# Training Performance:
#   Accuracy  : 1.0000
#   Precision : 1.0000
#   Recall    : 1.0000
#   F1 Score  : 1.0000
#   ROC AUC   : 1.0000
# Test Performance:
#   Accuracy  : 0.9807
#   Precision : 0.9879
#   Recall    : 0.8763
#   F1 Score  : 0.9288
#   ROC AUC   : 0.9373
# ==================================================
# 🔍 Model: SVC (Linear Kernel)
# Training Performance:
#   Accuracy  : 0.9997
#   Precision : 1.0000
#   Recall    : 0.9979
#   F1 Score  : 0.9989
#   ROC AUC   : 0.9989
# Test Performance:
#   Accuracy  : 0.9807
#   Precision : 0.9879
#   Recall    : 0.8763
#   F1 Score  : 0.9288
#   ROC AUC   : 0.9373
# ==================================================
# 🔍 Model: Decision Tree
# Training Performance:
#   Accuracy  : 1.0000
#   Precision : 1.0000
#   Recall    : 1.0000
#   F1 Score  : 1.0000
#   ROC AUC   : 1.0000
# Test Performance:
#   Accuracy  : 0.9528
#   Precision : 0.8613
#   Recall    : 0.8011
#   F1 Score  : 0.8301
#   ROC AUC   : 0.8897
# ==================================================
# 🔍 Model: Random Forest
# Training Performance:
#   Accuracy  : 0.9969
#   Precision : 1.0000
#   Recall    : 0.9743
#   F1 Score  : 0.9870
#   ROC AUC   : 1.0000
# Test Performance:
#   Accuracy  : 0.9698
#   Precision : 0.9933
#   Recall    : 0.7957
#   F1 Score  : 0.8836
#   ROC AUC   : 0.9850
# ==================================================
# 🔍 Model: Gaussian NB
# Training Performance:
#   Accuracy  : 0.9288
#   Precision : 0.6285
#   Recall    : 1.0000
#   F1 Score  : 0.7719
#   ROC AUC   : 0.9595
# Test Performance:
#   Accuracy  : 0.8732
#   Precision : 0.5367
#   Recall    : 0.8656
#   F1 Score  : 0.6626
#   ROC AUC   : 0.8700
# ==================================================
# 🔍 Model: Multinomial NB
# Training Performance:
#   Accuracy  : 0.9905
#   Precision : 0.9886
#   Recall    : 0.9315
#   F1 Score  : 0.9592
#   ROC AUC   : 0.9905
# Test Performance:
#   Accuracy  : 0.9776
#   Precision : 0.9337
#   Recall    : 0.9086
#   F1 Score  : 0.9210
#   ROC AUC   : 0.9691
# ==================================================
# 🔍 Model: Bernoulli NB
# Training Performance:
#   Accuracy  : 0.9992
#   Precision : 1.0000
#   Recall    : 0.9936
#   F1 Score  : 0.9968
#   ROC AUC   : 0.9999
# Test Performance:
#   Accuracy  : 0.9729
#   Precision : 0.9521
#   Recall    : 0.8548
#   F1 Score  : 0.9008
#   ROC AUC   : 0.9625
# ==================================================
# 🔍 Model: AdaBoost
# Training Performance:
#   Accuracy  : 1.0000
#   Precision : 1.0000
#   Recall    : 1.0000
#   F1 Score  : 1.0000
#   ROC AUC   : 1.0000
# Test Performance:
#   Accuracy  : 0.9745
#   Precision : 0.9474
#   Recall    : 0.8710
#   F1 Score  : 0.9076
#   ROC AUC   : 0.9675
# ==================================================
# 🔍 Model: XGBoost
# Training Performance:
#   Accuracy  : 0.9863
#   Precision : 0.9976
#   Recall    : 0.8887
#   F1 Score  : 0.9400
#   ROC AUC   : 0.9906
# Test Performance:
#   Accuracy  : 0.9722
#   Precision : 0.9573
#   Recall    : 0.8441
#   F1 Score  : 0.8971
#   ROC AUC   : 0.9824
# ==================================================

# %%
auc_models = [
    {
        'label': 'Logistic Regression Classifier',
        'model': LogisticRegression(solver='liblinear', penalty='l2', C=100, max_iter=1000)
    },
    {
        'label': 'XGBoost Classifier',
        'model': XGBClassifier(subsample=1, n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=1, use_label_encoder=False, eval_metric='logloss')
    },
]

plt.figure()

for algo in auc_models:
    model = algo['model']  # select the model
    model.fit(X_train, y_train)  # train the model
    
    # Compute False Positive Rate and True Positive Rate
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
    
    # Calculate AUC score dynamically
    auc_score = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])
    
    # Plot the ROC curve
    plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % (algo['label'], auc_score))

# Custom settings for the plot
plt.plot([0, 1], [0, 1], 'r--')  # diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('1-Specificity (False Positive Rate)')
plt.ylabel('Sensitivity (True Positive Rate)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")

# %%
import joblib

# %%
logreg_model = LogisticRegression(solver='liblinear', penalty='l2', C=100, max_iter=1000)
logreg_model.fit(X_train, y_train)

xgboost_model = XGBClassifier(subsample=1, n_estimators=500, max_depth=3, learning_rate=0.1, colsample_bytree=1, use_label_encoder=False, eval_metric='logloss')
xgboost_model.fit(X_train, y_train)

# Save all models using joblib
joblib.dump(logreg_model, 'logistic_regression_model.joblib')
joblib.dump(xgboost_model, 'xgboost_model.joblib')
joblib.dump(tfidf, 'tfidf_vectorizer.joblib')

print("All models and vectorizer saved using joblib.")
# Out:
# All models and vectorizer saved using joblib.
